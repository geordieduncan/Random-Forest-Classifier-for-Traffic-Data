# %%
import numpy as np

from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
#from mpl_toolkits.basemap import Basemap
import numpy as np
import pandas as pd
import glob
import csv
import datetime as dt
#import geopy
from matplotlib.dates import DateFormatter
import matplotlib.ticker as ticker
import xlrd
import math
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

# %%
data = csv.reader(open('TrafficDataReduced_v3.csv'))

# %%
cell = []
col = True
for i in data:

    if col == False:

    #starttime = dt.datetime.strptime('6/27/2018 00:00:00', '%m/%d/%Y %H:%M:%S')
    #T2 = dt.datetime.strptime(z[3], '%Y-%m-%d %H:%M:%S.%f')
    #T1 = T2 - dt.timedelta(minutes=60)
    #T3 = T2 + dt.timedelta(minutes=60)
        i[5]=dt.datetime.strptime(i[5], '%H:%M:%S') #.timestamp()
        cell.append(i)
    else:
        col_name = i
        col=False
    
df=pd.DataFrame(cell,columns = col_name)

# %%
#seaborn.pairplot(df, vars=[1,2,5,6],kind='reg',hue=8)
#sns.pairplot(df, vars=[1,2,5,6],kind='reg',hue=8)
sns.set(style="darkgrid")
sns.catplot(x='date',height=10,aspect=5, data=df, kind='count').set_xticklabels(rotation=90).savefig("output_date_all.png") # hue='incident_type'

# %%
sns.catplot(x='date',height=10,aspect=5,hue='incident_type', data=df, kind='count').set_xticklabels(rotation=90)

# %%
plt.figure(figsize=(20, 6))
sns.catplot(x='date',data=df,height=10,aspect=5,col='incident_dir', kind='count').set_xticklabels(rotation=90).savefig("output_date_nbsb.png") #.savefig("output_date_all.png")

# %%
#['cam_id', 'lat', 'long', 'am_dir', 'date', 'time', 'incident_type', 'incident_name', 'incident_dir', 'true_alarm', 'incident_location', 'accident or non-accident', '', '', '', '', '', '', '']

plt.figure(figsize=(20, 6))
sns.catplot(x='incident_type',data=df,col='incident_dir', kind='count').set_xticklabels(rotation=45).savefig("output_incident_type.png") #.savefig("output_date_all.png")

# %%
df['hour']=df['time'].dt.hour
sns.catplot(x='hour',col='incident_dir',data=df,kind='count').savefig("output_hour.png")

# %%
#['cam_id', 'lat', 'long', 'am_dir', 'date', 'time', 'incident_type', 'incident_name', 'incident_dir', 'true_alarm', 'incident_location', 'accident or non-accident', '', '', '', '', '', '', '']

sns.pairplot(df,vars=['hour','incident_type'],kind='reg',hue='incident_dir')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-bf769467a894> in <module>
#       1 #['cam_id', 'lat', 'long', 'am_dir', 'date', 'time', 'incident_type', 'incident_name', 'incident_dir', 'true_alarm', 'incident_location', 'accident or non-accident', '', '', '', '', '', '', '']
#       2
# ----> 3 sns.pairplot(df,vars=['hour','incident_type'],kind='reg',hue='incident_dir')
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2109             diag_kws.setdefault("shade", True)
#    2110             diag_kws["legend"] = False
# -> 2111             grid.map_diag(kdeplot, **diag_kws)
#    2112
#    2113     # Maybe plot on the off-diagonals
#
# ...

# %%
df.columns
# Out:
# Index(['cam_id', 'lat', 'long', 'cam_dir', 'date', 'time', 'incident_type',
#        'incident_name', 'incident_dir', 'true_alarm', 'incident_location',
#        'accident or non-accident', '', '', '', '', '', '', '', 'hour'],
#       dtype='object')

# %%
df['cam_id'][4]
# Out:
# 'N1C09'

# %%
df.iloc[1,1]
# Out:
# '32.92077604'

# %%
df.iloc[3]
# Out:
# cam_id                                                                  N2C01
# lat                                                               32.76613511
# long                                                             -83.71030216
# cam_dir                                                                     n
# date                                                                6/27/2018
# time                                                      1900-01-01 12:55:09
# incident_type                                                incident_stopped
# incident_name               2018-06-27_12-55-09_incident_stopped_zone_nb-s...
# incident_dir                                                               nb
# true_alarm                                                                  y
# incident_location                                                    shoulder
# accident or non-accident                                         non-accident
#
#
#
#
#
#
#
# ...
